# %% [markdown]
# # Indicator Method

# %% [markdown]
# Country---Country
#
# Year---Year
#
# Status---Developed or Developing status
#
# Life expectancy---Life Expectancy in age
#
# Adult Mortality---Adult Mortality Rates of both sexes (probability of dying between 15 and 60 years per 1000 population)
#
# infant deaths---Number of Infant Deaths per 1000 population
#
# Alcohol---Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)
#
# percentage expenditure---Expenditure on health as a percentage of Gross Domestic Product per capita(%)
#
# Hepatitis B---Hepatitis B (HepB) immunization coverage among 1-year-olds (%)
#
# Measles---Measles - number of reported cases per 1000 population

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df=pd.read_csv('Life_Expectancy_Data.csv')
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df['Country'].unique()
print(df['Year'].unique())
print(df['Status'].unique() )
# Out:
# [2015 2014 2013 2012 2011 2010 2009 2008 2007 2006 2005 2004 2003 2002
#  2001 2000]
# ['Developing' 'Developed']

# %%
df.drop('Country',axis=1,inplace=True)

# %% [markdown]
# coding some variables

# %%
# Import Label encoder
from sklearn import preprocessing


l=['Year','Status']
for i in l:
    label_encoder=preprocessing.LabelEncoder()
    
    label_encoder.fit(df[i])
    print(i,label_encoder.classes_)
    
    df[i]=label_encoder.transform(df[i])
    
df.head()
# Out:
# Year [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015]
# Status ['Developed' 'Developing']
#    Year  Status  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0    15       1              65.0            263.0             62     0.01
# 1    14       1              59.9            271.0             64     0.01
# 2    13       1              59.9            268.0             66     0.01
# 3    12       1              59.5            272.0             69     0.01
# 4    11       1              59.2            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# 0               71.279624         65.0      1154   19.1  ...    6.0
# 1               73.523582         62.0       492   18.6  ...   58.0
# 2               73.219243         64.0       430   18.1  ...   62.0
# 3               78.184215         67.0      2787   17.6  ...   67.0
# ...

# %% [markdown]
# # Replacing all null values with zero

# %%
df1=df.replace(np.nan,0) 
df1
# Out:
#       Year  Status  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0       15       1              65.0            263.0             62     0.01
# 1       14       1              59.9            271.0             64     0.01
# 2       13       1              59.9            268.0             66     0.01
# 3       12       1              59.5            272.0             69     0.01
# 4       11       1              59.2            275.0             71     0.01
# ...    ...     ...               ...              ...            ...      ...
# 2933     4       1              44.3            723.0             27     4.36
# 2934     3       1              44.5            715.0             26     4.06
# 2935     2       1              44.8             73.0             25     4.43
# 2936     1       1              45.3            686.0             25     1.72
# 2937     0       1              46.0            665.0             24     1.68
#
# ...

# %% [markdown]
# Known completely-----------------------------
#
# infant deaths                        0
#
# percentage expenditure               0
#
# Measles                              0
#
# under-five deaths                    0
#
# HIV/AIDS                            0
#
# Unknown variables---------------------------

# %%
df1.isnull().sum()
# Out:
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
y=df1['Life expectancy ']
x=df1[['Year', 'Status', 'Adult Mortality','infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
       'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure','Diphtheria ', ' HIV/AIDS', 'GDP', 
       'Population',' thinness  1-19 years', ' thinness 5-9 years','Income composition of resources', 'Schooling']]
np.shape(x)
# Out:
# (2938, 20)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=101)
print(x_train.shape)
print(x_test.shape)
# Out:
# (2056, 20)
# (882, 20)

# %% [markdown]
# # Evaluating  using regression model

# %%
from sklearn.linear_model import LinearRegression

lm=LinearRegression()

lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Prediction
y_pred=lm.predict(x_test);
#y_pred

# %%
print("Intercept :\n ",lm.intercept_)
print("coefficients :\n ",lm.coef_)
print("R square : \n", lm.score(x_train,y_train))
# Out:
# Intercept :
#   61.47841688588956
# coefficients :
#   [-5.04870966e-03 -2.86933629e+00 -1.55889643e-02  1.38180319e-01
#   2.92875785e-01 -1.28644370e-04  1.02288648e-02 -2.58813680e-07
#   4.37733763e-02 -1.04132072e-01  3.05227954e-02 -8.14147786e-02
#   1.91422887e-02 -5.04826853e-01  8.21884873e-05 -4.94531534e-10
#  -1.02526426e-01  2.61365418e-02  6.66778263e+00  2.05348028e-01]
# R square :
#  0.6509642288862714

# %%
plt.scatter(y_test,y_pred)

# %%
# MAE,MSE and RMSE
from math import sqrt
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

MAE1=mean_absolute_error(y_test,y_pred)
MSE1=mean_squared_error(y_test,y_pred)
RMSE1=sqrt(MSE1)

print("MAE1: ",MAE1)
print("MSE1: ",MSE1)
print("RMSE1: ",RMSE1)
# Out:
# MAE1:  3.3592014972651034
# MSE1:  28.42778879171363
# RMSE1:  5.331771637243444

# %%
print("R square : \n", lm.score(x_train,y_train))
# Out:
# R square :
#  0.6509642288862714

# %% [raw]
# Thus this model explained 65.09 % variability in life expentancy when missing values are replace using regression model .
